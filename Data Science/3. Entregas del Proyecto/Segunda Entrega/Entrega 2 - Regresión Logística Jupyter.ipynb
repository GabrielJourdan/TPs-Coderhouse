# %% [markdown]
# ## ALGORITMO DE CLASIFICACION

# %% [markdown]
# # APLICACION DE MODELO LOGISTIC REGRESSION

# %%
#obtenicon de librerias:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import warnings

warnings.filterwarnings("ignore")

import ipywidgets as widgets #librearia para interaccion del usuario con los graficos
import missingno as msno

from scipy.stats import norm
from scipy import stats

from statsmodels.graphics.gofplots import qqplot

from prettytable import PrettyTable

from statistics import median
 

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.compose import make_column_selector

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score, auc, roc_auc_score

# %%
#Función para pasar a minúsculas los string de una lista o array
def to_lowercase(arr):
 new_arr = []
 for x in list(range(0,len(arr))):
   new = arr[x].lower()
   new_arr.append(new)
 return new_arr

# %%
#Funcion para extraer el primer digito de una lista o array

def getFirstDigit(num):
    while num >= 10:
        num = int(num/10)
    return num

# %%
#Determinar cuántas columnas y rows queremos que nos muestre por defecto
pd.options.display.max_rows = 100
pd.options.display.max_columns = 200

# %%
#Obtencion de los datos:
data=pd.read_csv("https://raw.githubusercontent.com/johanjohnson/DataCleaning---ChurnDataSet/main/churn_raw_data.csv")
df=pd.DataFrame(data)
df.head(2)
# Out:
#    Unnamed: 0  CaseOrder Customer_id                           Interaction  \
# 0           1          1     K409198  aa90260b-4141-4a24-8e36-b04ce1f4f77b
# 1           2          2     S120509  fb76459f-c047-4a9d-8af9-e0f7d4ac2524
#
#           City State                 County    Zip       Lat        Lng  \
# 0  Point Baker    AK  Prince of Wales-Hyder  99927  56.25100 -133.37571
# 1  West Branch    MI                 Ogemaw  48661  44.32893  -84.24080
#
#    Population   Area         Timezone                                Job  \
# 0          38  Urban    America/Sitka  Environmental health practitioner
# 1       10446  Urban  America/Detroit             Programmer, multimedia
#
#    Children   Age                    Education Employment    Income  Marital  \
# 0       NaN  68.0              Master's Degree  Part Time  28561.99  Widowed
# 1       1.0  27.0  Regular High School Diploma    Retired  21704.77  Married
#
#    Gender Churn  Outage_sec_perweek  Email  Contacts  Yearly_equip_failure  \
# 0    Male    No            6.972566     10         0                     1
# 1  Female   Yes           12.014541     12         0                     1
#
#   Techie        Contract Port_modem Tablet InternetService Phone Multiple  \
# 0     No        One year        Yes    Yes     Fiber Optic   Yes       No
# 1    Yes  Month-to-month         No    Yes     Fiber Optic   Yes      Yes
#
#   OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0            Yes          Yes               No          No          No
# 1            Yes           No               No          No         Yes
#
#   StreamingMovies PaperlessBilling             PaymentMethod    Tenure  \
# 0             Yes              Yes   Credit Card (automatic)  6.795513
# 1             Yes              Yes  Bank Transfer(automatic)  1.156681
#
#    MonthlyCharge  Bandwidth_GB_Year  item1  item2  item3  item4  item5  item6  \
# 0     171.449762         904.536110      5      5      5      3      4      4
# 1     242.948015         800.982766      3      4      3      3      4      3
#
#    item7  item8
# 0      3      4
# 1      4      4

# %%
#creo un df 'original' para volver e casos necesarios
original= df
df = original.copy(deep=True)

# %% [markdown]
# ## Manipulacion de datos de todo el dataset

# %%
# Crear una variable booleana de churn con 0 y 1 

df['Churn_bool']=df['Churn'].apply(lambda x: 1 if x == 'Yes' else 0)
df['Churn_bool']
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       1
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: Churn_bool, Length: 10000, dtype: int64

# %% [markdown]
# ###*Creacion de nuevas variables*

# %%
#Borramos la primer columna porque son índices
df.drop('Unnamed: 0',axis=1,inplace=True)
df.head(3)
# Out:
#    CaseOrder Customer_id                           Interaction         City  \
# 0          1     K409198  aa90260b-4141-4a24-8e36-b04ce1f4f77b  Point Baker
# 1          2     S120509  fb76459f-c047-4a9d-8af9-e0f7d4ac2524  West Branch
# 2          3     K191035  344d114c-3736-4be5-98f7-c72c281e2d35      Yamhill
#
#   State                 County    Zip       Lat        Lng  Population   Area  \
# 0    AK  Prince of Wales-Hyder  99927  56.25100 -133.37571          38  Urban
# 1    MI                 Ogemaw  48661  44.32893  -84.24080       10446  Urban
# 2    OR                Yamhill  97148  45.35589 -123.24657        3735  Urban
#
#               Timezone                                Job  Children   Age  \
# 0        America/Sitka  Environmental health practitioner       NaN  68.0
# 1      America/Detroit             Programmer, multimedia       1.0  27.0
# 2  America/Los_Angeles            Chief Financial Officer       4.0  50.0
#
#                      Education Employment    Income  Marital  Gender Churn  \
# 0              Master's Degree  Part Time  28561.99  Widowed    Male    No
# 1  Regular High School Diploma    Retired  21704.77  Married  Female   Yes
# 2  Regular High School Diploma    Student       NaN  Widowed  Female    No
#
#    Outage_sec_perweek  Email  Contacts  Yearly_equip_failure Techie  \
# 0            6.972566     10         0                     1     No
# 1           12.014541     12         0                     1    Yes
# 2           10.245616      9         0                     1    Yes
#
#          Contract Port_modem Tablet InternetService Phone Multiple  \
# 0        One year        Yes    Yes     Fiber Optic   Yes       No
# 1  Month-to-month         No    Yes     Fiber Optic   Yes      Yes
# 2        Two Year        Yes     No             DSL   Yes      Yes
#
#   OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0            Yes          Yes               No          No          No
# 1            Yes           No               No          No         Yes
# 2             No           No               No          No          No
#
#   StreamingMovies PaperlessBilling             PaymentMethod     Tenure  \
# 0             Yes              Yes   Credit Card (automatic)   6.795513
# 1             Yes              Yes  Bank Transfer(automatic)   1.156681
# 2             Yes              Yes   Credit Card (automatic)  15.754144
#
#    MonthlyCharge  Bandwidth_GB_Year  item1  item2  item3  item4  item5  item6  \
# 0     171.449762         904.536110      5      5      5      3      4      4
# 1     242.948015         800.982766      3      4      3      3      4      3
# 2     159.440398        2054.706961      4      4      2      4      4      3
#
#    item7  item8  Churn_bool
# 0      3      4           0
# 1      4      4           1
# 2      3      3           0

# %%
#pasamos a minuscula la primera letra del encabezado
col_names = to_lowercase(df.columns.values)

df.set_axis(col_names,axis='columns',inplace=True)

df.columns.values
# Out:
# array(['caseorder', 'customer_id', 'interaction', 'city', 'state',
#        'county', 'zip', 'lat', 'lng', 'population', 'area', 'timezone',
#        'job', 'children', 'age', 'education', 'employment', 'income',
#        'marital', 'gender', 'churn', 'outage_sec_perweek', 'email',
#        'contacts', 'yearly_equip_failure', 'techie', 'contract',
#        'port_modem', 'tablet', 'internetservice', 'phone', 'multiple',
#        'onlinesecurity', 'onlinebackup', 'deviceprotection',
#        'techsupport', 'streamingtv', 'streamingmovies',
#        'paperlessbilling', 'paymentmethod', 'tenure', 'monthlycharge',
#        'bandwidth_gb_year', 'item1', 'item2', 'item3', 'item4', 'item5',
#        'item6', 'item7', 'item8', 'churn_bool'], dtype=object)

# %%
#Variable que unifique los valores obtenidos en la encuesta

df['total_encuesta']=df.item1.values+df.item2.values+df.item3.values+df.item4.values+df.item5.values+df.item6.values+df.item7.values+df.item8.values
df['total_encuesta']
# Out:
# 0       33
# 1       28
# 2       27
# 3       29
# 4       32
#         ..
# 9995    23
# 9996    34
# 9997    33
# 9998    33
# 9999    21
# Name: total_encuesta, Length: 10000, dtype: int64

# %%
#Cambiar los nombres de las últimas columnas reemplazar itemx por el nombre del item:

factores_items = {'item1': 'timely_response', 
                  'item2': 'timely_fixes', 
                  'item3': 'timely_replacements', 
                  'item4': 'reliability', 
                  'item5': 'options',
                  'item6': 'respectful_response',
                  'item7': 'courteous_exchange',
                  'item8': 'active_listening'}

df.rename(columns=factores_items, inplace=True)

df.head(2)
# Out:
#    caseorder customer_id                           interaction         city  \
# 0          1     K409198  aa90260b-4141-4a24-8e36-b04ce1f4f77b  Point Baker
# 1          2     S120509  fb76459f-c047-4a9d-8af9-e0f7d4ac2524  West Branch
#
#   state                 county    zip       lat        lng  population   area  \
# 0    AK  Prince of Wales-Hyder  99927  56.25100 -133.37571          38  Urban
# 1    MI                 Ogemaw  48661  44.32893  -84.24080       10446  Urban
#
#           timezone                                job  children   age  \
# 0    America/Sitka  Environmental health practitioner       NaN  68.0
# 1  America/Detroit             Programmer, multimedia       1.0  27.0
#
#                      education employment    income  marital  gender churn  \
# 0              Master's Degree  Part Time  28561.99  Widowed    Male    No
# 1  Regular High School Diploma    Retired  21704.77  Married  Female   Yes
#
#    outage_sec_perweek  email  contacts  yearly_equip_failure techie  \
# 0            6.972566     10         0                     1     No
# 1           12.014541     12         0                     1    Yes
#
#          contract port_modem tablet internetservice phone multiple  \
# 0        One year        Yes    Yes     Fiber Optic   Yes       No
# 1  Month-to-month         No    Yes     Fiber Optic   Yes      Yes
#
#   onlinesecurity onlinebackup deviceprotection techsupport streamingtv  \
# 0            Yes          Yes               No          No          No
# 1            Yes           No               No          No         Yes
#
#   streamingmovies paperlessbilling             paymentmethod    tenure  \
# 0             Yes              Yes   Credit Card (automatic)  6.795513
# 1             Yes              Yes  Bank Transfer(automatic)  1.156681
#
#    monthlycharge  bandwidth_gb_year  timely_response  timely_fixes  \
# 0     171.449762         904.536110                5             5
# 1     242.948015         800.982766                3             4
#
#    timely_replacements  reliability  options  respectful_response  \
# 0                    5            3        4                    4
# 1                    3            3        4                    3
#
#    courteous_exchange  active_listening  churn_bool  total_encuesta
# 0                   3                 4           0              33
# 1                   4                 4           1              28

# %%
#Nuevas variables que cuentan la cantidad de cada tipo de servicios y el total de servicios que los clientes contratan

df['q_online_serv'] = df.internetservice.apply(lambda x: 1 if x in ['Fiber Optic', 'DSL'] else 0).values +df.onlinesecurity.apply(lambda x: 1 if x == 'Yes' else 0).values + df.onlinebackup.apply(lambda x: 1 if x == 'Yes' else 0).values+df.techsupport.apply(lambda x: 1 if x== 'Yes' else 0).values
df['q_phone_serv']=df.phone.apply(lambda x: 1 if x == 'Yes' else 0).values+df.deviceprotection.apply(lambda x: 1 if x == 'Yes' else 0).values
df['q_streaming'] = df.streamingtv.apply(lambda x:1 if x=='Yes' else 0).values + df.streamingmovies.apply(lambda x:1 if x=='Yes'else 0).values

df['q_total_serv']=df['q_online_serv'].values+df['q_phone_serv'].values+df['q_streaming'].values

# %%
#Creacion de variable zip_zone agrupando los zip teniendo en cuenta su primer digito quen indica una de las 9 zonas generales de EEUU

df['zip_zone'] = df.zip.apply(lambda x: getFirstDigit(x))
df.groupby('zip_zone').count()
# Out:
#           caseorder  customer_id  interaction  city  state  county   zip  \
# zip_zone
# 1              1216         1216         1216  1216   1216    1216  1216
# 2              1177         1177         1177  1177   1177    1177  1177
# 3              1140         1140         1140  1140   1140    1140  1140
# 4              1228         1228         1228  1228   1228    1228  1228
# 5              1170         1170         1170  1170   1170    1170  1170
# 6              1183         1183         1183  1183   1183    1183  1183
# 7              1236         1236         1236  1236   1236    1236  1236
# 8               710          710          710   710    710     710   710
# 9               940          940          940   940    940     940   940
#
#            lat   lng  population  area  timezone   job  children  age  \
# zip_zone
# 1         1216  1216        1216  1216      1216  1216       908  916
# 2         1177  1177        1177  1177      1177  1177       903  897
# 3         1140  1140        1140  1140      1140  1140       868  878
# 4         1228  1228        1228  1228      1228  1228       926  925
# 5         1170  1170        1170  1170      1170  1170       877  885
# 6         1183  1183        1183  1183      1183  1183       849  862
# 7         1236  1236        1236  1236      1236  1236       948  898
# 8          710   710         710   710       710   710       537  528
# 9          940   940         940   940       940   940       689  736
#
#           education  employment  income  marital  gender  churn  \
# zip_zone
# 1              1216        1216     911     1216    1216   1216
# 2              1177        1177     903     1177    1177   1177
# 3              1140        1140     853     1140    1140   1140
# 4              1228        1228     899     1228    1228   1228
# 5              1170        1170     875     1170    1170   1170
# 6              1183        1183     904     1183    1183   1183
# 7              1236        1236     933     1236    1236   1236
# 8               710         710     521      710     710    710
# 9               940         940     711      940     940    940
#
#           outage_sec_perweek  email  contacts  yearly_equip_failure  techie  \
# zip_zone
# 1                       1216   1216      1216                  1216     922
# 2                       1177   1177      1177                  1177     901
# 3                       1140   1140      1140                  1140     852
# 4                       1228   1228      1228                  1228     941
# 5                       1170   1170      1170                  1170     867
# 6                       1183   1183      1183                  1183     872
# 7                       1236   1236      1236                  1236     934
# 8                        710    710       710                   710     523
# 9                        940    940       940                   940     711
#
#           contract  port_modem  tablet  internetservice  phone  multiple  \
# zip_zone
# 1             1216        1216    1216             1216   1067      1216
# 2             1177        1177    1177             1177   1057      1177
# 3             1140        1140    1140             1140   1016      1140
# 4             1228        1228    1228             1228   1117      1228
# 5             1170        1170    1170             1170   1046      1170
# 6             1183        1183    1183             1183   1066      1183
# 7             1236        1236    1236             1236   1104      1236
# 8              710         710     710              710    645       710
# 9              940         940     940              940    856       940
#
#           onlinesecurity  onlinebackup  deviceprotection  techsupport  \
# zip_zone
# 1                   1216          1216              1216         1108
# 2                   1177          1177              1177         1054
# 3                   1140          1140              1140         1043
# 4                   1228          1228              1228         1112
# 5                   1170          1170              1170         1058
# 6                   1183          1183              1183         1059
# 7                   1236          1236              1236         1097
# 8                    710           710               710          627
# 9                    940           940               940          851
#
#           streamingtv  streamingmovies  paperlessbilling  paymentmethod  \
# zip_zone
# 1                1216             1216              1216           1216
# 2                1177             1177              1177           1177
# 3                1140             1140              1140           1140
# 4                1228             1228              1228           1228
# 5                1170             1170              1170           1170
# 6                1183             1183              1183           1183
# 7                1236             1236              1236           1236
# 8                 710              710               710            710
# 9                 940              940               940            940
#
#           tenure  monthlycharge  bandwidth_gb_year  timely_response  \
# zip_zone
# 1           1082           1216               1100             1216
# 2           1081           1177               1064             1177
# 3           1039           1140               1023             1140
# 4           1102           1228               1101             1228
# 5           1061           1170               1058             1170
# 6           1099           1183               1064             1183
# 7           1116           1236               1109             1236
# 8            637            710                629              710
# 9            852            940                831              940
#
#           timely_fixes  timely_replacements  reliability  options  \
# zip_zone
# 1                 1216                 1216         1216     1216
# 2                 1177                 1177         1177     1177
# 3                 1140                 1140         1140     1140
# 4                 1228                 1228         1228     1228
# 5                 1170                 1170         1170     1170
# 6                 1183                 1183         1183     1183
# 7                 1236                 1236         1236     1236
# 8                  710                  710          710      710
# 9                  940                  940          940      940
#
#           respectful_response  courteous_exchange  active_listening  \
# zip_zone
# 1                        1216                1216              1216
# 2                        1177                1177              1177
# 3                        1140                1140              1140
# 4                        1228                1228              1228
# 5                        1170                1170              1170
# 6                        1183                1183              1183
# 7                        1236                1236              1236
# 8                         710                 710               710
# 9                         940                 940               940
#
#           churn_bool  total_encuesta  q_online_serv  q_phone_serv  \
# zip_zone
# 1               1216            1216           1216          1216
# 2               1177            1177           1177          1177
# 3               1140            1140           1140          1140
# 4               1228            1228           1228          1228
# 5               1170            1170           1170          1170
# 6               1183            1183           1183          1183
# 7               1236            1236           1236          1236
# 8                710             710            710           710
# 9                940             940            940           940
#
#           q_streaming  q_total_serv
# zip_zone
# 1                1216          1216
# 2                1177          1177
# 3                1140          1140
# 4                1228          1228
# 5                1170          1170
# 6                1183          1183
# 7                1236          1236
# 8                 710           710
# 9                 940           940

# %%
#contactos vs tenure

df['contacts_by_month'] = df['contacts']/df['tenure']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 59 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   caseorder             10000 non-null  int64
#  1   customer_id           10000 non-null  object
#  2   interaction           10000 non-null  object
#  3   city                  10000 non-null  object
#  4   state                 10000 non-null  object
#  5   county                10000 non-null  object
#  6   zip                   10000 non-null  int64
#  7   lat                   10000 non-null  float64
#  8   lng                   10000 non-null  float64
#  9   population            10000 non-null  int64
#  10  area                  10000 non-null  object
#  11  timezone              10000 non-null  object
#  12  job                   10000 non-null  object
#  13  children              7505 non-null   float64
#  14  age                   7525 non-null   float64
#  15  education             10000 non-null  object
#  16  employment            10000 non-null  object
#  17  income                7510 non-null   float64
#  18  marital               10000 non-null  object
#  19  gender                10000 non-null  object
#  20  churn                 10000 non-null  object
#  21  outage_sec_perweek    10000 non-null  float64
#  22  email                 10000 non-null  int64
#  23  contacts              10000 non-null  int64
#  24  yearly_equip_failure  10000 non-null  int64
#  25  techie                7523 non-null   object
#  26  contract              10000 non-null  object
#  27  port_modem            10000 non-null  object
#  28  tablet                10000 non-null  object
#  29  internetservice       10000 non-null  object
#  30  phone                 8974 non-null   object
#  31  multiple              10000 non-null  object
#  32  onlinesecurity        10000 non-null  object
#  33  onlinebackup          10000 non-null  object
#  34  deviceprotection      10000 non-null  object
#  35  techsupport           9009 non-null   object
#  36  streamingtv           10000 non-null  object
#  37  streamingmovies       10000 non-null  object
#  38  paperlessbilling      10000 non-null  object
#  39  paymentmethod         10000 non-null  object
#  40  tenure                9069 non-null   float64
#  41  monthlycharge         10000 non-null  float64
#  42  bandwidth_gb_year     8979 non-null   float64
#  43  timely_response       10000 non-null  int64
#  44  timely_fixes          10000 non-null  int64
#  45  timely_replacements   10000 non-null  int64
#  46  reliability           10000 non-null  int64
#  47  options               10000 non-null  int64
#  48  respectful_response   10000 non-null  int64
#  49  courteous_exchange    10000 non-null  int64
#  50  active_listening      10000 non-null  int64
#  51  churn_bool            10000 non-null  int64
#  52  total_encuesta        10000 non-null  int64
#  53  q_online_serv         10000 non-null  int64
#  54  q_phone_serv          10000 non-null  int64
#  55  q_streaming           10000 non-null  int64
#  56  q_total_serv          10000 non-null  int64
#  57  zip_zone              10000 non-null  int64
#  58  contacts_by_month     9069 non-null   float64
# dtypes: float64(10), int64(21), object(28)
# memory usage: 4.5+ MB

# %%
df.head(1)
# Out:
#    caseorder customer_id                           interaction         city  \
# 0          1     K409198  aa90260b-4141-4a24-8e36-b04ce1f4f77b  Point Baker
#
#   state                 county    zip     lat        lng  population   area  \
# 0    AK  Prince of Wales-Hyder  99927  56.251 -133.37571          38  Urban
#
#         timezone                                job  children   age  \
# 0  America/Sitka  Environmental health practitioner       NaN  68.0
#
#          education employment    income  marital gender churn  \
# 0  Master's Degree  Part Time  28561.99  Widowed   Male    No
#
#    outage_sec_perweek  email  contacts  yearly_equip_failure techie  contract  \
# 0            6.972566     10         0                     1     No  One year
#
#   port_modem tablet internetservice phone multiple onlinesecurity  \
# 0        Yes    Yes     Fiber Optic   Yes       No            Yes
#
#   onlinebackup deviceprotection techsupport streamingtv streamingmovies  \
# 0          Yes               No          No          No             Yes
#
#   paperlessbilling            paymentmethod    tenure  monthlycharge  \
# 0              Yes  Credit Card (automatic)  6.795513     171.449762
#
#    bandwidth_gb_year  timely_response  timely_fixes  timely_replacements  \
# 0          904.53611                5             5                    5
#
#    reliability  options  respectful_response  courteous_exchange  \
# 0            3        4                    4                   3
#
#    active_listening  churn_bool  total_encuesta  q_online_serv  q_phone_serv  \
# 0                 4           0              33              3             1
#
#    q_streaming  q_total_serv  zip_zone  contacts_by_month
# 0            1             5         9                0.0

# %% [markdown]
# ###*Eliminado de varibales que no son significativas para el modelo*

# %%
#las dejo comentadas porque vamos a aplicar PCA

#Eliminamos las variables que no necesitamos vamos a utilizar:

df.drop([ 'caseorder', 'customer_id', 'interaction', 'city',
       'state', 'county', 'zip', 'timezone', 'job', 'education'],axis=1,inplace=True)

df.drop('churn', axis=1, inplace=True)

# %% [markdown]
# ##Spliteo

# %%
# split input y target

X = df.drop('churn_bool', axis=1)
y = df['churn_bool']

#split de modelo
from sklearn.model_selection import train_test_split

X_train , X_test, y_train, y_test = train_test_split(X,y , test_size=0.2, random_state=10, stratify=y)


print(X_train.shape, y_train.shape)
# Out:
# (8000, 47) (8000,)

# %%
print("Partición de entrenamento")
print("-----------------------")
print(y_train.describe())
# Out:
# Partición de entrenamento
# -----------------------
# count    8000.000000
# mean        0.265000
# std         0.441361
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: churn_bool, dtype: float64

# %%
print("Partición de test")
print("-----------------------")
print(y_test.describe())
# Out:
# Partición de test
# -----------------------
# count    2000.000000
# mean        0.265000
# std         0.441444
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: churn_bool, dtype: float64

# %% [markdown]
# ###*Rellenado de valores nulos*

# %%
X_train.isnull().sum()[X_train.isnull().sum()>0]
# Out:
# children             1984
# age                  1986
# income               1996
# techie               1970
# phone                 805
# techsupport           801
# tenure                736
# bandwidth_gb_year     803
# contacts_by_month     736
# dtype: int64

# %%
#Rellenado de variable children con la mediana de la agrupacion

#creo datarrame de referencia

children_ref_null = X_train.groupby(['gender','marital','employment']).median()['children'].reset_index()
children_ref_null
# Out:
#                   gender        marital  employment  children
# 0                 Female       Divorced   Full Time       2.0
# 1                 Female       Divorced   Part Time       2.0
# 2                 Female       Divorced     Retired       2.0
# 3                 Female       Divorced     Student       1.0
# 4                 Female       Divorced  Unemployed       1.0
# 5                 Female        Married   Full Time       1.0
# 6                 Female        Married   Part Time       2.0
# 7                 Female        Married     Retired       1.0
# 8                 Female        Married     Student       1.5
# 9                 Female        Married  Unemployed       1.0
# 10                Female  Never Married   Full Time       1.0
# 11                Female  Never Married   Part Time       1.0
# 12                Female  Never Married     Retired       2.0
# 13                Female  Never Married     Student       1.0
# 14                Female  Never Married  Unemployed       2.0
# 15                Female      Separated   Full Time       1.0
# 16                Female      Separated   Part Time       1.0
# 17                Female      Separated     Retired       1.0
# 18                Female      Separated     Student       1.0
# 19                Female      Separated  Unemployed       2.0
# 20                Female        Widowed   Full Time       2.0
# 21                Female        Widowed   Part Time       2.0
# 22                Female        Widowed     Retired       1.0
# 23                Female        Widowed     Student       1.0
# 24                Female        Widowed  Unemployed       1.0
# 25                  Male       Divorced   Full Time       1.0
# 26                  Male       Divorced   Part Time       1.0
# 27                  Male       Divorced     Retired       1.0
# 28                  Male       Divorced     Student       1.0
# 29                  Male       Divorced  Unemployed       1.0
# 30                  Male        Married   Full Time       2.0
# 31                  Male        Married   Part Time       1.0
# 32                  Male        Married     Retired       1.5
# 33                  Male        Married     Student       2.0
# 34                  Male        Married  Unemployed       2.0
# 35                  Male  Never Married   Full Time       1.0
# 36                  Male  Never Married   Part Time       2.0
# 37                  Male  Never Married     Retired       2.0
# 38                  Male  Never Married     Student       1.0
# 39                  Male  Never Married  Unemployed       2.0
# 40                  Male      Separated   Full Time       1.0
# 41                  Male      Separated   Part Time       1.0
# 42                  Male      Separated     Retired       2.0
# 43                  Male      Separated     Student       1.0
# 44                  Male      Separated  Unemployed       1.0
# 45                  Male        Widowed   Full Time       2.0
# 46                  Male        Widowed   Part Time       2.0
# 47                  Male        Widowed     Retired       2.0
# 48                  Male        Widowed     Student       2.0
# 49                  Male        Widowed  Unemployed       1.0
# 50  Prefer not to answer       Divorced   Full Time       2.0
# 51  Prefer not to answer       Divorced   Part Time       1.0
# 52  Prefer not to answer       Divorced     Retired       1.5
# 53  Prefer not to answer       Divorced     Student       0.0
# 54  Prefer not to answer       Divorced  Unemployed       1.0
# 55  Prefer not to answer        Married   Full Time       1.0
# 56  Prefer not to answer        Married   Part Time       2.0
# 57  Prefer not to answer        Married     Retired       2.5
# 58  Prefer not to answer        Married     Student       3.0
# 59  Prefer not to answer        Married  Unemployed       8.0
# 60  Prefer not to answer  Never Married   Full Time       3.0
# 61  Prefer not to answer  Never Married   Part Time       3.0
# 62  Prefer not to answer  Never Married     Retired       0.0
# 63  Prefer not to answer  Never Married     Student       4.0
# 64  Prefer not to answer  Never Married  Unemployed       NaN
# 65  Prefer not to answer      Separated   Full Time       2.0
# 66  Prefer not to answer      Separated   Part Time       1.0
# 67  Prefer not to answer      Separated     Retired       3.0
# 68  Prefer not to answer      Separated     Student       1.0
# 69  Prefer not to answer      Separated  Unemployed       2.0
# 70  Prefer not to answer        Widowed   Full Time       2.0
# 71  Prefer not to answer        Widowed   Part Time       3.0
# 72  Prefer not to answer        Widowed     Retired       2.0
# 73  Prefer not to answer        Widowed     Student       2.0
# 74  Prefer not to answer        Widowed  Unemployed       0.0

# %%
#funcion de replace en base a dataframe agrupado
def fill_na_children_grouped(df_grouped , row_replace):
  if pd.isna(row_replace['children']):
    return df_grouped[(df_grouped['gender'] == row_replace['gender'])&(df_grouped['marital'] == row_replace['marital'])&(df_grouped['employment'] == row_replace['employment'])]['children'].values[0]
  else:
    return row_replace['children']


#transformacion de train
X_train['children'] = X_train.apply(lambda row: fill_na_children_grouped(children_ref_null, row), axis=1)

X_train.isnull().sum()
# Out:
# lat                        0
# lng                        0
# population                 0
# area                       0
# children                   2
# age                     1986
# employment                 0
# income                  1996
# marital                    0
# gender                     0
# outage_sec_perweek         0
# email                      0
# contacts                   0
# yearly_equip_failure       0
# techie                  1970
# contract                   0
# port_modem                 0
# tablet                     0
# internetservice            0
# phone                    805
# multiple                   0
# onlinesecurity             0
# onlinebackup               0
# deviceprotection           0
# techsupport              801
# streamingtv                0
# streamingmovies            0
# paperlessbilling           0
# paymentmethod              0
# tenure                   736
# monthlycharge              0
# bandwidth_gb_year        803
# timely_response            0
# timely_fixes               0
# timely_replacements        0
# reliability                0
# options                    0
# respectful_response        0
# courteous_exchange         0
# active_listening           0
# total_encuesta             0
# q_online_serv              0
# q_phone_serv               0
# q_streaming                0
# q_total_serv               0
# zip_zone                   0
# contacts_by_month        736
# dtype: int64

# %%
#obtencion de la moda de la variable children para rellenar los 2 nulos restantes.
train_children_mode = X_train['children'].mode()[0]
X_train.children = X_train.children.fillna(train_children_mode)
train_children_mode 
X_train.isnull().sum()
# Out:
# lat                        0
# lng                        0
# population                 0
# area                       0
# children                   0
# age                     1986
# employment                 0
# income                  1996
# marital                    0
# gender                     0
# outage_sec_perweek         0
# email                      0
# contacts                   0
# yearly_equip_failure       0
# techie                  1970
# contract                   0
# port_modem                 0
# tablet                     0
# internetservice            0
# phone                    805
# multiple                   0
# onlinesecurity             0
# onlinebackup               0
# deviceprotection           0
# techsupport              801
# streamingtv                0
# streamingmovies            0
# paperlessbilling           0
# paymentmethod              0
# tenure                   736
# monthlycharge              0
# bandwidth_gb_year        803
# timely_response            0
# timely_fixes               0
# timely_replacements        0
# reliability                0
# options                    0
# respectful_response        0
# courteous_exchange         0
# active_listening           0
# total_encuesta             0
# q_online_serv              0
# q_phone_serv               0
# q_streaming                0
# q_total_serv               0
# zip_zone                   0
# contacts_by_month        736
# dtype: int64

# %%
#Rellenado de variable age con la mediana de la agrupacion

#creo datarrame de referencia

age_ref_null = X_train.groupby(['gender','marital','employment']).median()['age'].reset_index()
age_ref_null

#funcion de replace en base a dataframe agrupado
def fill_na_age_grouped(df_grouped , row_replace):
  if pd.isna(row_replace['age']):
    return df_grouped[(df_grouped['gender'] == row_replace['gender'])&(df_grouped['marital'] == row_replace['marital'])&(df_grouped['employment'] == row_replace['employment'])]['age'].values[0]
  else:
    return row_replace['age']


#transformacion de train
X_train['age'] = X_train.apply(lambda row: fill_na_age_grouped(age_ref_null, row), axis=1)

X_train.isnull().sum()
# Out:
# lat                        0
# lng                        0
# population                 0
# area                       0
# children                   0
# age                        2
# employment                 0
# income                  1996
# marital                    0
# gender                     0
# outage_sec_perweek         0
# email                      0
# contacts                   0
# yearly_equip_failure       0
# techie                  1970
# contract                   0
# port_modem                 0
# tablet                     0
# internetservice            0
# phone                    805
# multiple                   0
# onlinesecurity             0
# onlinebackup               0
# deviceprotection           0
# techsupport              801
# streamingtv                0
# streamingmovies            0
# paperlessbilling           0
# paymentmethod              0
# tenure                   736
# monthlycharge              0
# bandwidth_gb_year        803
# timely_response            0
# timely_fixes               0
# timely_replacements        0
# reliability                0
# options                    0
# respectful_response        0
# courteous_exchange         0
# active_listening           0
# total_encuesta             0
# q_online_serv              0
# q_phone_serv               0
# q_streaming                0
# q_total_serv               0
# zip_zone                   0
# contacts_by_month        736
# dtype: int64

# %%
#obtencion de la moda de la variable age para rellenar los 2 nulos restantes.
train_age_mode = X_train['age'].mode()[0]
X_train.age = X_train.age.fillna(train_age_mode)
train_age_mode 
#X_train.isnull().sum()
# Out:
# 53.0

# %%
#Rellenado de variable income con la media de la agrupacion

#creo dataframe de referencia

income_ref_null = X_train.groupby(['gender','marital','employment']).mean()['income'].reset_index()
income_ref_null

#funcion de replace en base a dataframe agrupado
def fill_na_income_grouped(df_grouped , row_replace):
  if pd.isna(row_replace['income']):
    return df_grouped[(df_grouped['gender'] == row_replace['gender'])&(df_grouped['marital'] == row_replace['marital'])&(df_grouped['employment'] == row_replace['employment'])]['income'].values[0]
  else:
    return row_replace['income']


#transformacion de train
X_train['income'] = X_train.apply(lambda row: fill_na_income_grouped(income_ref_null, row), axis=1)

X_train.isnull().sum()
# Out:
# lat                        0
# lng                        0
# population                 0
# area                       0
# children                   0
# age                        0
# employment                 0
# income                     0
# marital                    0
# gender                     0
# outage_sec_perweek         0
# email                      0
# contacts                   0
# yearly_equip_failure       0
# techie                  1970
# contract                   0
# port_modem                 0
# tablet                     0
# internetservice            0
# phone                    805
# multiple                   0
# onlinesecurity             0
# onlinebackup               0
# deviceprotection           0
# techsupport              801
# streamingtv                0
# streamingmovies            0
# paperlessbilling           0
# paymentmethod              0
# tenure                   736
# monthlycharge              0
# bandwidth_gb_year        803
# timely_response            0
# timely_fixes               0
# timely_replacements        0
# reliability                0
# options                    0
# respectful_response        0
# courteous_exchange         0
# active_listening           0
# total_encuesta             0
# q_online_serv              0
# q_phone_serv               0
# q_streaming                0
# q_total_serv               0
# zip_zone                   0
# contacts_by_month        736
# dtype: int64

# %%
#Rellenado de variable techie con NS/NC
X_train['techie'].fillna('NS/NC', inplace=True)
#Rellenado de variable phone con NS/NC
X_train['phone'].fillna('NS/NC', inplace=True)
#Rellenado de variable techsupport con NS/NC
X_train['techsupport'].fillna('NS/NC', inplace=True)
#Rellenado de variable tenure con 0 haciendo referencia a 0 meses transcurridos desde la firma de contrato
X_train['tenure'].fillna(0, inplace=True)

# %%
#Rellenado de variable bandwidth_gb_year con la mediana de la agrupacion

#creo datarrame de referencia

band_ref_null = X_train.groupby(['contract','q_streaming']).median()['bandwidth_gb_year'].reset_index()
band_ref_null

#funcion de replace en base a dataframe agrupado
def fill_na_band_grouped(df_grouped , row_replace):
  if pd.isna(row_replace['bandwidth_gb_year']):
    return df_grouped[(df_grouped['contract'] == row_replace['contract'])&(df_grouped['q_streaming'] == row_replace['q_streaming'])]['bandwidth_gb_year'].values[0]
  else:
    return row_replace['bandwidth_gb_year']


#transformacion de train
X_train['bandwidth_gb_year'] = X_train.apply(lambda row: fill_na_band_grouped(band_ref_null, row), axis=1)

X_train.isnull().sum()
# Out:
# lat                       0
# lng                       0
# population                0
# area                      0
# children                  0
# age                       0
# employment                0
# income                    0
# marital                   0
# gender                    0
# outage_sec_perweek        0
# email                     0
# contacts                  0
# yearly_equip_failure      0
# techie                    0
# contract                  0
# port_modem                0
# tablet                    0
# internetservice           0
# phone                     0
# multiple                  0
# onlinesecurity            0
# onlinebackup              0
# deviceprotection          0
# techsupport               0
# streamingtv               0
# streamingmovies           0
# paperlessbilling          0
# paymentmethod             0
# tenure                    0
# monthlycharge             0
# bandwidth_gb_year         0
# timely_response           0
# timely_fixes              0
# timely_replacements       0
# reliability               0
# options                   0
# respectful_response       0
# courteous_exchange        0
# active_listening          0
# total_encuesta            0
# q_online_serv             0
# q_phone_serv              0
# q_streaming               0
# q_total_serv              0
# zip_zone                  0
# contacts_by_month       736
# dtype: int64

# %%
X_train['contacts_by_month'].fillna(X_train['contacts'],inplace=True)

# %% [markdown]
# ###*Agrupado de valores en variables categoricas*

# %%
#No lo considero necesario en esta primer prueba del moedelo ya que 
#la categoria con mayor cantidad de valores es employment que tiene 5. Aceptable para one hot encoding

# %%
X_train.employment.value_counts()
# Out:
# Full Time     4796
# Part Time      819
# Retired        809
# Unemployed     799
# Student        777
# Name: employment, dtype: int64

# %% [markdown]
# ###*Transformacion de variables cuantitativas*

# %%
numeric_cols = X_train.select_dtypes(include=['float64', 'int'])
numeric_cols.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8000 entries, 117 to 7678
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   lat                   8000 non-null   float64
#  1   lng                   8000 non-null   float64
#  2   population            8000 non-null   int64
#  3   children              8000 non-null   float64
#  4   age                   8000 non-null   float64
#  5   income                8000 non-null   float64
#  6   outage_sec_perweek    8000 non-null   float64
#  7   email                 8000 non-null   int64
#  8   contacts              8000 non-null   int64
#  9   yearly_equip_failure  8000 non-null   int64
#  10  tenure                8000 non-null   float64
#  11  monthlycharge         8000 non-null   float64
#  12  bandwidth_gb_year     8000 non-null   float64
#  13  timely_response       8000 non-null   int64
#  14  timely_fixes          8000 non-null   int64
#  15  timely_replacements   8000 non-null   int64
#  16  reliability           8000 non-null   int64
#  17  options               8000 non-null   int64
#  18  respectful_response   8000 non-null   int64
#  19  courteous_exchange    8000 non-null   int64
#  20  active_listening      8000 non-null   int64
#  21  total_encuesta        8000 non-null   int64
#  22  q_online_serv         8000 non-null   int64
#  23  q_phone_serv          8000 non-null   int64
#  24  q_streaming           8000 non-null   int64
#  25  q_total_serv          8000 non-null   int64
#  26  zip_zone              8000 non-null   int64
#  27  contacts_by_month     8000 non-null   float64
# dtypes: float64(10), int64(18)
# memory usage: 1.8 MB

# %%
cat_cols = X_train.select_dtypes(include=['object', 'category']).columns#.to_list()
cat_cols
# Out:
# Index(['area', 'employment', 'marital', 'gender', 'techie', 'contract',
#        'port_modem', 'tablet', 'internetservice', 'phone', 'multiple',
#        'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
#        'streamingtv', 'streamingmovies', 'paperlessbilling', 'paymentmethod'],
#       dtype='object')

# %%
#seleccion de columnas normalizadas
normal_cols = []

#loop en todas las columnas del x_train
for col in numeric_cols.columns:

  #calculo de D'Agostino's K-squared test
  k2, p_value = stats.normaltest(numeric_cols[col])
  #chequeo de si p-value es mayor a 0.05
  if p_value > 0.05:
    normal_cols.append(col)
  
  #print de todas las variables con su valor
  print(f"columna {col} -----Estadístico = {k2}, p-value = {p_value}")

#seleccion de las variables que no estan en normal,  nos daran el resto de columnas no seleccionadas
not_stander = list(set(numeric_cols.columns) - set(normal_cols))
# Out:
# columna lat -----Estadístico = 598.9648717769833, p-value = 8.638347420348221e-131
# columna lng -----Estadístico = 1944.9342021055136, p-value = 0.0
# columna population -----Estadístico = 3642.4907579125947, p-value = 0.0
# columna children -----Estadístico = 2813.0022002800924, p-value = 0.0
# columna age -----Estadístico = 328.1089906539104, p-value = 5.649863404187498e-72
# columna income -----Estadístico = 2829.16315249172, p-value = 0.0
# columna outage_sec_perweek -----Estadístico = 4954.294254782738, p-value = 0.0
# columna email -----Estadístico = 0.06573239470491196, p-value = 0.9676680274712856
# columna contacts -----Estadístico = 1042.8042507791943, p-value = 3.6135501857577665e-227
# columna yearly_equip_failure -----Estadístico = 2484.1481262706293, p-value = 0.0
# columna tenure -----Estadístico = 34439.38532146221, p-value = 0.0
# columna monthlycharge -----Estadístico = 281.38396166393716, p-value = 7.911322281899981e-62
# columna bandwidth_gb_year -----Estadístico = 41786.649220303996, p-value = 0.0
# columna timely_response -----Estadístico = 6.996684909960948, p-value = 0.030247478450725823
# columna timely_fixes -----Estadístico = 5.56538134912787, p-value = 0.06187180631330251
# columna timely_replacements -----Estadístico = 8.890056021716994, p-value = 0.011736777269130739
# columna reliability -----Estadístico = 5.6838156614569275, p-value = 0.05831430594545343
# columna options -----Estadístico = 8.768902132306184, p-value = 0.01246973131351432
# columna respectful_response -----Estadístico = 17.42371184224075, p-value = 0.0001646224445098171
# columna courteous_exchange -----Estadístico = 1.9455841564728507, p-value = 0.37802608483765826
# columna active_listening -----Estadístico = 3.9962533154342417, p-value = 0.13558905016701125
# columna total_encuesta -----Estadístico = 4.358632678964328, p-value = 0.11311883909518247
# columna q_online_serv -----Estadístico = 80.53610099172532, p-value = 3.2494351395806423e-18
# columna q_phone_serv -----Estadístico = 363.9745174869611, p-value = 9.20317649854195e-80
# columna q_streaming -----Estadístico = 1570.1212011027037, p-value = 0.0
# columna q_total_serv -----Estadístico = 40.67637207488758, p-value = 1.4697316006123886e-09
# columna zip_zone -----Estadístico = 3948.6079347293644, p-value = 0.0
# columna contacts_by_month -----Estadístico = 6839.683603748685, p-value = 0.0

# %%
normal_cols
# Out:
# ['email',
#  'timely_fixes',
#  'reliability',
#  'courteous_exchange',
#  'active_listening',
#  'total_encuesta']

# %%
not_stander
# Out:
# ['q_phone_serv',
#  'timely_response',
#  'options',
#  'q_total_serv',
#  'q_online_serv',
#  'lng',
#  'tenure',
#  'outage_sec_perweek',
#  'contacts',
#  'lat',
#  'bandwidth_gb_year',
#  'population',
#  'age',
#  'yearly_equip_failure',
#  'contacts_by_month',
#  'zip_zone',
#  'children',
#  'income',
#  'monthlycharge',
#  'q_streaming',
#  'timely_replacements',
#  'respectful_response']

# %%
#proceso de transformacion en X_train

#standarizacion es el z-score utilizado para variables ya con distribucion normal
sc = StandardScaler()
X_train[normal_cols] = sc.fit_transform(X_train[normal_cols])

#utilizacion para cambiar el valor con una distribucion mas desconocida
rs = RobustScaler()
X_train[not_stander] = rs.fit_transform(X_train[not_stander])


X_train
# Out:
#            lat       lng  population      area  children       age employment  \
# 117   0.196199 -0.531688   -0.146230     Urban       0.5  1.062500  Part Time
# 1133 -0.203567 -1.028791    0.089329  Suburban      -0.5 -1.395833    Student
# 9860  0.153765 -0.594810   -0.165252     Rural       3.5 -0.979167  Full Time
# 8531 -0.592631 -0.649899    0.600541     Urban       0.0 -0.270833  Full Time
# 8917 -0.512668 -0.042412   -0.124585  Suburban      -0.5 -0.645833  Full Time
# ...        ...       ...         ...       ...       ...       ...        ...
# 8429 -0.155296  0.529973    0.024802     Rural       1.5  0.229167  Full Time
# 2738 -1.785348  0.323905    0.407617  Suburban       0.0  0.000000  Full Time
# 834  -0.054807  0.485890   -0.161399     Rural       0.0 -0.062500  Full Time
# 5632  0.203393  0.378490    0.736400  Suburban       0.0 -0.229167  Part Time
# 7678  0.111907 -1.004091    0.152708  Suburban       0.0 -0.645833  Full Time
#
#         income    marital  gender  outage_sec_perweek     email  contacts  \
# 117   0.541610   Divorced  Female            0.293001 -0.005632       1.0
# 1133 -1.217060   Divorced  Female           -0.284959 -0.668199      -0.5
# 9860 -1.126608    Married    Male            6.711489 -0.999483      -0.5
# 8531 -0.501662    Married  Female           -0.050139 -0.336915       0.0
# 8917 -1.110740    Married    Male           -0.604125 -0.005632      -0.5
# ...        ...        ...     ...                 ...       ...       ...
# 8429  0.007454  Separated  Female           -0.383251  1.650787       0.0
# 2738 -0.650334  Separated  Female           -0.813467  0.325652      -0.5
# 834   0.281816  Separated    Male            1.104406 -0.336915      -0.5
# 5632  0.043767  Separated  Female           -0.720046 -0.668199       0.0
# 7678 -1.390159  Separated  Female           -0.009361 -0.336915       1.5
#
#       yearly_equip_failure techie        contract port_modem tablet  \
# 117                    0.0  NS/NC        Two Year         No    Yes
# 1133                   0.0     No  Month-to-month         No    Yes
# 9860                   0.0     No  Month-to-month         No     No
# 8531                   1.0     No  Month-to-month         No    Yes
# 8917                   1.0  NS/NC        Two Year         No     No
# ...                    ...    ...             ...        ...    ...
# 8429                   0.0    Yes  Month-to-month        Yes    Yes
# 2738                   0.0  NS/NC        One year         No     No
# 834                    0.0     No  Month-to-month         No     No
# 5632                   0.0     No  Month-to-month        Yes     No
# 7678                   0.0     No  Month-to-month        Yes     No
#
#      internetservice  phone multiple onlinesecurity onlinebackup  \
# 117      Fiber Optic    Yes      Yes             No          Yes
# 1133            None    Yes      Yes             No           No
# 9860     Fiber Optic     No       No             No           No
# 8531     Fiber Optic  NS/NC       No             No          Yes
# 8917     Fiber Optic    Yes       No             No           No
# ...              ...    ...      ...            ...          ...
# 8429             DSL    Yes       No             No           No
# 2738     Fiber Optic    Yes       No            Yes          Yes
# 834      Fiber Optic    Yes      Yes             No           No
# 5632             DSL    Yes      Yes            Yes           No
# 7678     Fiber Optic    Yes       No             No          Yes
#
#      deviceprotection techsupport streamingtv streamingmovies  \
# 117               Yes          No         Yes             Yes
# 1133              Yes          No         Yes             Yes
# 9860              Yes          No          No             Yes
# 8531               No         Yes          No              No
# 8917              Yes          No          No              No
# ...               ...         ...         ...             ...
# 8429               No       NS/NC         Yes              No
# 2738               No          No         Yes             Yes
# 834                No          No         Yes              No
# 5632              Yes          No          No              No
# 7678               No         Yes          No             Yes
#
#      paperlessbilling             paymentmethod    tenure  monthlycharge  \
# 117               Yes          Electronic Check -0.086711       1.696821
# 1133              Yes          Electronic Check -0.290487       0.830044
# 9860               No   Credit Card (automatic) -0.317895       0.290333
# 8531               No   Credit Card (automatic)  0.944347      -0.370278
# 8917               No          Electronic Check  0.455183      -0.760554
# ...               ...                       ...       ...            ...
# 8429               No   Credit Card (automatic) -0.317895      -0.896066
# 2738              Yes          Electronic Check -0.198250       1.019250
# 834                No          Electronic Check -0.202360       0.014393
# 5632               No  Bank Transfer(automatic)  0.729310      -0.505033
# 7678              Yes          Electronic Check  0.874225       0.196728
#
#       bandwidth_gb_year  timely_response  timely_fixes  timely_replacements  \
# 117           -0.342360              1.0      1.441404                  1.0
# 1133          -0.552458              0.0     -1.456861                 -1.0
# 9860           0.621508              1.0      0.475316                  1.0
# 8531           0.645062             -1.0     -1.456861                 -2.0
# 8917           0.127728              1.0      1.441404                  3.0
# ...                 ...              ...           ...                  ...
# 8429           0.760540              1.0     -0.490773                  1.0
# 2738          -0.485588              2.0     -0.490773                  2.0
# 834           -0.521691              1.0     -1.456861                  1.0
# 5632           0.537567              1.0      1.441404                  1.0
# 7678           0.607834             -1.0     -1.456861                 -2.0
#
#       reliability  options  respectful_response  courteous_exchange  \
# 117      0.491062     -2.0                  1.0            0.467559
# 1133    -2.429029      1.0                 -1.0            0.467559
# 9860     0.491062     -2.0                  1.0            2.413696
# 8531     2.437789      0.0                  2.0           -1.478578
# 8917     1.464425     -1.0                  1.0            0.467559
# ...           ...      ...                  ...                 ...
# 8429    -0.482302      2.0                  0.0           -0.505509
# 2738    -1.455665      1.0                  0.0           -0.505509
# 834      0.491062      0.0                  0.0            1.440628
# 5632    -0.482302      1.0                  0.0            0.467559
# 7678     0.491062      1.0                  0.0            0.467559
#
#       active_listening  total_encuesta  q_online_serv  q_phone_serv  \
# 117           0.487782        0.460913            0.0           1.0
# 1133         -0.489982       -1.615791           -1.0           1.0
# 9860          0.487782        0.691658           -0.5           0.0
# 8531          0.487782       -0.692811            0.5          -1.0
# 8917          1.465547        1.614637           -0.5           1.0
# ...                ...             ...            ...           ...
# 8429         -0.489982       -0.000577           -0.5           0.0
# 2738         -1.467747       -0.231322            0.5           0.0
# 834           1.465547        0.460913           -0.5           0.0
# 5632         -0.489982        0.460913            0.0           1.0
# 7678          0.487782       -0.923556            0.5           0.0
#
#       q_streaming  q_total_serv  zip_zone  contacts_by_month
# 117           1.0           1.0      0.25           1.716407
# 1133          1.0           0.0      0.75          -0.150382
# 9860          0.0          -0.5      0.25          -0.150382
# 8531         -1.0          -0.5      0.50          -0.036412
# 8917         -1.0          -0.5     -0.50          -0.150382
# ...           ...           ...       ...                ...
# 8429          0.0          -0.5     -0.75           7.679541
# 2738          1.0           1.0     -0.50          -0.150382
# 834           0.0          -0.5     -0.75          -0.150382
# 5632         -1.0           0.0     -0.25          -0.013009
# 7678          0.0           0.5      0.75           0.332311
#
# [8000 rows x 47 columns]

# %% [markdown]
# ###Transformacion de categoricas en variables dummy con One Hot Encoder

# %%
cat_cols
# Out:
# Index(['area', 'employment', 'marital', 'gender', 'techie', 'contract',
#        'port_modem', 'tablet', 'internetservice', 'phone', 'multiple',
#        'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
#        'streamingtv', 'streamingmovies', 'paperlessbilling', 'paymentmethod'],
#       dtype='object')

# %%
#generate one hot encoder class
encoder = OneHotEncoder(handle_unknown='ignore', #ponemos ignore para poder ommitir cuando puede pasar que no exista los mismos valores.LE DAMOS FLEXIBILIDAD AL MODELO0 
                        sparse=False,drop='if_binary') # generarlo como. matrix para poder generar las columnas adecuadas

#entrenamiento para genera el preprocesamiento one hot encoding para las variables indicadas
encoder.fit(X_train[cat_cols])

#extraigo los nombres de las columnas para usar de diccionario
encoder_cols=encoder.get_feature_names_out(cat_cols)

#transformo en train datasets en base a la clase generada
cat_encoding = pd.DataFrame(encoder.transform(X_train[cat_cols]), columns=encoder_cols)
cat_encoding.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 44 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   area_Rural                              8000 non-null   float64
#  1   area_Suburban                           8000 non-null   float64
#  2   area_Urban                              8000 non-null   float64
#  3   employment_Full Time                    8000 non-null   float64
#  4   employment_Part Time                    8000 non-null   float64
#  5   employment_Retired                      8000 non-null   float64
#  6   employment_Student                      8000 non-null   float64
#  7   employment_Unemployed                   8000 non-null   float64
#  8   marital_Divorced                        8000 non-null   float64
#  9   marital_Married                         8000 non-null   float64
#  10  marital_Never Married                   8000 non-null   float64
#  11  marital_Separated                       8000 non-null   float64
#  12  marital_Widowed                         8000 non-null   float64
#  13  gender_Female                           8000 non-null   float64
#  14  gender_Male                             8000 non-null   float64
#  15  gender_Prefer not to answer             8000 non-null   float64
#  16  techie_NS/NC                            8000 non-null   float64
#  17  techie_No                               8000 non-null   float64
#  18  techie_Yes                              8000 non-null   float64
#  19  contract_Month-to-month                 8000 non-null   float64
#  20  contract_One year                       8000 non-null   float64
#  21  contract_Two Year                       8000 non-null   float64
#  22  port_modem_Yes                          8000 non-null   float64
#  23  tablet_Yes                              8000 non-null   float64
#  24  internetservice_DSL                     8000 non-null   float64
#  25  internetservice_Fiber Optic             8000 non-null   float64
#  26  internetservice_None                    8000 non-null   float64
#  27  phone_NS/NC                             8000 non-null   float64
#  28  phone_No                                8000 non-null   float64
#  29  phone_Yes                               8000 non-null   float64
#  30  multiple_Yes                            8000 non-null   float64
#  31  onlinesecurity_Yes                      8000 non-null   float64
#  32  onlinebackup_Yes                        8000 non-null   float64
#  33  deviceprotection_Yes                    8000 non-null   float64
#  34  techsupport_NS/NC                       8000 non-null   float64
#  35  techsupport_No                          8000 non-null   float64
#  36  techsupport_Yes                         8000 non-null   float64
#  37  streamingtv_Yes                         8000 non-null   float64
#  38  streamingmovies_Yes                     8000 non-null   float64
#  39  paperlessbilling_Yes                    8000 non-null   float64
#  40  paymentmethod_Bank Transfer(automatic)  8000 non-null   float64
#  41  paymentmethod_Credit Card (automatic)   8000 non-null   float64
#  42  paymentmethod_Electronic Check          8000 non-null   float64
#  43  paymentmethod_Mailed Check              8000 non-null   float64
# dtypes: float64(44)
# memory usage: 2.7 MB

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8000 entries, 117 to 7678
# Data columns (total 47 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   lat                   8000 non-null   float64
#  1   lng                   8000 non-null   float64
#  2   population            8000 non-null   float64
#  3   area                  8000 non-null   object
#  4   children              8000 non-null   float64
#  5   age                   8000 non-null   float64
#  6   employment            8000 non-null   object
#  7   income                8000 non-null   float64
#  8   marital               8000 non-null   object
#  9   gender                8000 non-null   object
#  10  outage_sec_perweek    8000 non-null   float64
#  11  email                 8000 non-null   float64
#  12  contacts              8000 non-null   float64
#  13  yearly_equip_failure  8000 non-null   float64
#  14  techie                8000 non-null   object
#  15  contract              8000 non-null   object
#  16  port_modem            8000 non-null   object
#  17  tablet                8000 non-null   object
#  18  internetservice       8000 non-null   object
#  19  phone                 8000 non-null   object
#  20  multiple              8000 non-null   object
#  21  onlinesecurity        8000 non-null   object
#  22  onlinebackup          8000 non-null   object
#  23  deviceprotection      8000 non-null   object
#  24  techsupport           8000 non-null   object
#  25  streamingtv           8000 non-null   object
#  26  streamingmovies       8000 non-null   object
#  27  paperlessbilling      8000 non-null   object
#  28  paymentmethod         8000 non-null   object
#  29  tenure                8000 non-null   float64
#  30  monthlycharge         8000 non-null   float64
#  31  bandwidth_gb_year     8000 non-null   float64
#  32  timely_response       8000 non-null   float64
#  33  timely_fixes          8000 non-null   float64
#  34  timely_replacements   8000 non-null   float64
#  35  reliability           8000 non-null   float64
#  36  options               8000 non-null   float64
#  37  respectful_response   8000 non-null   float64
#  38  courteous_exchange    8000 non-null   float64
#  39  active_listening      8000 non-null   float64
#  40  total_encuesta        8000 non-null   float64
#  41  q_online_serv         8000 non-null   float64
#  42  q_phone_serv          8000 non-null   float64
#  43  q_streaming           8000 non-null   float64
#  44  q_total_serv          8000 non-null   float64
#  45  zip_zone              8000 non-null   float64
#  46  contacts_by_month     8000 non-null   float64
# dtypes: float64(28), object(19)
# memory usage: 2.9+ MB

# %%
# Reseteamos el index para poder concatenarlo con el df de los cat_encoding:(si no hago esto,se alarga el dataset)

X_train.reset_index(inplace = True, drop=True)
y_train.reset_index(inplace = True, drop=True)

# %%
#joineo de las variables que deseo con categoricas encoding CON EL DF. AGREGO COLUMNAS AL DF
X_all_train = pd.concat([X_train, cat_encoding], axis=1)


#Borrado de columnas no necesarias
X_all_train.drop(['area', 'employment', 'marital', 'gender', 'techie', 'contract',
       'port_modem', 'tablet', 'internetservice', 'phone', 'multiple',
       'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
       'streamingtv', 'streamingmovies', 'paperlessbilling', 'paymentmethod'],axis=1, inplace=True)

#train datasets final
X_all_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 72 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   lat                                     8000 non-null   float64
#  1   lng                                     8000 non-null   float64
#  2   population                              8000 non-null   float64
#  3   children                                8000 non-null   float64
#  4   age                                     8000 non-null   float64
#  5   income                                  8000 non-null   float64
#  6   outage_sec_perweek                      8000 non-null   float64
#  7   email                                   8000 non-null   float64
#  8   contacts                                8000 non-null   float64
#  9   yearly_equip_failure                    8000 non-null   float64
#  10  tenure                                  8000 non-null   float64
#  11  monthlycharge                           8000 non-null   float64
#  12  bandwidth_gb_year                       8000 non-null   float64
#  13  timely_response                         8000 non-null   float64
#  14  timely_fixes                            8000 non-null   float64
#  15  timely_replacements                     8000 non-null   float64
#  16  reliability                             8000 non-null   float64
#  17  options                                 8000 non-null   float64
#  18  respectful_response                     8000 non-null   float64
#  19  courteous_exchange                      8000 non-null   float64
#  20  active_listening                        8000 non-null   float64
#  21  total_encuesta                          8000 non-null   float64
#  22  q_online_serv                           8000 non-null   float64
#  23  q_phone_serv                            8000 non-null   float64
#  24  q_streaming                             8000 non-null   float64
#  25  q_total_serv                            8000 non-null   float64
#  26  zip_zone                                8000 non-null   float64
#  27  contacts_by_month                       8000 non-null   float64
#  28  area_Rural                              8000 non-null   float64
#  29  area_Suburban                           8000 non-null   float64
#  30  area_Urban                              8000 non-null   float64
#  31  employment_Full Time                    8000 non-null   float64
#  32  employment_Part Time                    8000 non-null   float64
#  33  employment_Retired                      8000 non-null   float64
#  34  employment_Student                      8000 non-null   float64
#  35  employment_Unemployed                   8000 non-null   float64
#  36  marital_Divorced                        8000 non-null   float64
#  37  marital_Married                         8000 non-null   float64
#  38  marital_Never Married                   8000 non-null   float64
#  39  marital_Separated                       8000 non-null   float64
#  40  marital_Widowed                         8000 non-null   float64
#  41  gender_Female                           8000 non-null   float64
#  42  gender_Male                             8000 non-null   float64
#  43  gender_Prefer not to answer             8000 non-null   float64
#  44  techie_NS/NC                            8000 non-null   float64
#  45  techie_No                               8000 non-null   float64
#  46  techie_Yes                              8000 non-null   float64
#  47  contract_Month-to-month                 8000 non-null   float64
#  48  contract_One year                       8000 non-null   float64
#  49  contract_Two Year                       8000 non-null   float64
#  50  port_modem_Yes                          8000 non-null   float64
#  51  tablet_Yes                              8000 non-null   float64
#  52  internetservice_DSL                     8000 non-null   float64
#  53  internetservice_Fiber Optic             8000 non-null   float64
#  54  internetservice_None                    8000 non-null   float64
#  55  phone_NS/NC                             8000 non-null   float64
#  56  phone_No                                8000 non-null   float64
#  57  phone_Yes                               8000 non-null   float64
#  58  multiple_Yes                            8000 non-null   float64
#  59  onlinesecurity_Yes                      8000 non-null   float64
#  60  onlinebackup_Yes                        8000 non-null   float64
#  61  deviceprotection_Yes                    8000 non-null   float64
#  62  techsupport_NS/NC                       8000 non-null   float64
#  63  techsupport_No                          8000 non-null   float64
#  64  techsupport_Yes                         8000 non-null   float64
#  65  streamingtv_Yes                         8000 non-null   float64
#  66  streamingmovies_Yes                     8000 non-null   float64
#  67  paperlessbilling_Yes                    8000 non-null   float64
#  68  paymentmethod_Bank Transfer(automatic)  8000 non-null   float64
#  69  paymentmethod_Credit Card (automatic)   8000 non-null   float64
#  70  paymentmethod_Electronic Check          8000 non-null   float64
#  71  paymentmethod_Mailed Check              8000 non-null   float64
# dtypes: float64(72)
# memory usage: 4.4 MB

# %%
X_all_train.isnull().sum()[X_all_train.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ##*Entrenamiento con Train*

# %% [markdown]
# **Sugerencias**
#
# Como modelo lineal , se debe transformar la data , en lo posible normalizarla
#
# omitir los outliers
#
# no tener colinealidad entre variables, si hay varialbes muy relacionadas , borrar una
#
# Que los Datasets sean grandes , + de 2000 datos

# %%
# crear el clasificador
clf = LogisticRegression(C=1, n_jobs=-1, random_state=34, penalty='l2')

# Entrenar el modelo usando el conjunto de entranamiento
clf.fit(X_all_train, y_train)
# Out:
# LogisticRegression(C=1, n_jobs=-1, random_state=34)

# %% [markdown]
# ##*Transformacion del Test con lo entrenado*

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 2585 to 8967
# Data columns (total 47 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   lat                   2000 non-null   float64
#  1   lng                   2000 non-null   float64
#  2   population            2000 non-null   int64
#  3   area                  2000 non-null   object
#  4   children              1489 non-null   float64
#  5   age                   1511 non-null   float64
#  6   employment            2000 non-null   object
#  7   income                1506 non-null   float64
#  8   marital               2000 non-null   object
#  9   gender                2000 non-null   object
#  10  outage_sec_perweek    2000 non-null   float64
#  11  email                 2000 non-null   int64
#  12  contacts              2000 non-null   int64
#  13  yearly_equip_failure  2000 non-null   int64
#  14  techie                1493 non-null   object
#  15  contract              2000 non-null   object
#  16  port_modem            2000 non-null   object
#  17  tablet                2000 non-null   object
#  18  internetservice       2000 non-null   object
#  19  phone                 1779 non-null   object
#  20  multiple              2000 non-null   object
#  21  onlinesecurity        2000 non-null   object
#  22  onlinebackup          2000 non-null   object
#  23  deviceprotection      2000 non-null   object
#  24  techsupport           1810 non-null   object
#  25  streamingtv           2000 non-null   object
#  26  streamingmovies       2000 non-null   object
#  27  paperlessbilling      2000 non-null   object
#  28  paymentmethod         2000 non-null   object
#  29  tenure                1805 non-null   float64
#  30  monthlycharge         2000 non-null   float64
#  31  bandwidth_gb_year     1782 non-null   float64
#  32  timely_response       2000 non-null   int64
#  33  timely_fixes          2000 non-null   int64
#  34  timely_replacements   2000 non-null   int64
#  35  reliability           2000 non-null   int64
#  36  options               2000 non-null   int64
#  37  respectful_response   2000 non-null   int64
#  38  courteous_exchange    2000 non-null   int64
#  39  active_listening      2000 non-null   int64
#  40  total_encuesta        2000 non-null   int64
#  41  q_online_serv         2000 non-null   int64
#  42  q_phone_serv          2000 non-null   int64
#  43  q_streaming           2000 non-null   int64
#  44  q_total_serv          2000 non-null   int64
#  45  zip_zone              2000 non-null   int64
#  46  contacts_by_month     1805 non-null   float64
# dtypes: float64(10), int64(18), object(19)
# memory usage: 750.0+ KB

# %% [markdown]
# ####Rellenado con lo entrenado

# %%
X_test.isnull().sum()[X_test.isnull().sum()>0]
# Out:
# children             511
# age                  489
# income               494
# techie               507
# phone                221
# techsupport          190
# tenure               195
# bandwidth_gb_year    218
# contacts_by_month    195
# dtype: int64

# %%
#Rellenado de variable children
X_test['children'] = X_test.apply(lambda row: fill_na_children_grouped(children_ref_null, row), axis=1)

# %%
#Rellenado de variable age
X_test['age'] = X_test.apply(lambda row: fill_na_age_grouped(age_ref_null, row), axis=1)

# %%
#Rellenado de variable income
X_test['income'] = X_test.apply(lambda row: fill_na_income_grouped(income_ref_null, row), axis=1)

# %%
#Rellenado de variable techie con NS/NC
X_test['techie'].fillna('NS/NC', inplace=True)

# %%
#Rellenado de variable phone con NS/NC
X_test['phone'].fillna('NS/NC', inplace=True)

# %%
#Rellenado de variable techsupport con NS/NC
X_test['techsupport'].fillna('NS/NC', inplace=True)

# %%
#Rellenado de variable tenure con 0 haciendo referencia a 0 meses transcurridos desde la firma de contrato
X_test['tenure'].fillna(0, inplace=True)

X_test.isnull().sum()
# Out:
# lat                       0
# lng                       0
# population                0
# area                      0
# children                  0
# age                       0
# employment                0
# income                    0
# marital                   0
# gender                    0
# outage_sec_perweek        0
# email                     0
# contacts                  0
# yearly_equip_failure      0
# techie                    0
# contract                  0
# port_modem                0
# tablet                    0
# internetservice           0
# phone                     0
# multiple                  0
# onlinesecurity            0
# onlinebackup              0
# deviceprotection          0
# techsupport               0
# streamingtv               0
# streamingmovies           0
# paperlessbilling          0
# paymentmethod             0
# tenure                    0
# monthlycharge             0
# bandwidth_gb_year       218
# timely_response           0
# timely_fixes              0
# timely_replacements       0
# reliability               0
# options                   0
# respectful_response       0
# courteous_exchange        0
# active_listening          0
# total_encuesta            0
# q_online_serv             0
# q_phone_serv              0
# q_streaming               0
# q_total_serv              0
# zip_zone                  0
# contacts_by_month       195
# dtype: int64

# %%
#Rellenado de variable bandwidth_gb_year 
X_test['bandwidth_gb_year'] = X_test.apply(lambda row: fill_na_band_grouped(band_ref_null, row),axis=1)

# %%
#Rellenado de variable contacts_by_month 
#X_test['contacts_by_month'] = X_test.apply(lambda row: fill_na_contact_grouped(contact_ref_null, row), axis=1)
#X_train.isnull().sum()
X_test['contacts_by_month'].fillna(X_test['contacts'],inplace=True)
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 2585 to 8967
# Data columns (total 47 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   lat                   2000 non-null   float64
#  1   lng                   2000 non-null   float64
#  2   population            2000 non-null   int64
#  3   area                  2000 non-null   object
#  4   children              2000 non-null   float64
#  5   age                   2000 non-null   float64
#  6   employment            2000 non-null   object
#  7   income                2000 non-null   float64
#  8   marital               2000 non-null   object
#  9   gender                2000 non-null   object
#  10  outage_sec_perweek    2000 non-null   float64
#  11  email                 2000 non-null   int64
#  12  contacts              2000 non-null   int64
#  13  yearly_equip_failure  2000 non-null   int64
#  14  techie                2000 non-null   object
#  15  contract              2000 non-null   object
#  16  port_modem            2000 non-null   object
#  17  tablet                2000 non-null   object
#  18  internetservice       2000 non-null   object
#  19  phone                 2000 non-null   object
#  20  multiple              2000 non-null   object
#  21  onlinesecurity        2000 non-null   object
#  22  onlinebackup          2000 non-null   object
#  23  deviceprotection      2000 non-null   object
#  24  techsupport           2000 non-null   object
#  25  streamingtv           2000 non-null   object
#  26  streamingmovies       2000 non-null   object
#  27  paperlessbilling      2000 non-null   object
#  28  paymentmethod         2000 non-null   object
#  29  tenure                2000 non-null   float64
#  30  monthlycharge         2000 non-null   float64
#  31  bandwidth_gb_year     2000 non-null   float64
#  32  timely_response       2000 non-null   int64
#  33  timely_fixes          2000 non-null   int64
#  34  timely_replacements   2000 non-null   int64
#  35  reliability           2000 non-null   int64
#  36  options               2000 non-null   int64
#  37  respectful_response   2000 non-null   int64
#  38  courteous_exchange    2000 non-null   int64
#  39  active_listening      2000 non-null   int64
#  40  total_encuesta        2000 non-null   int64
#  41  q_online_serv         2000 non-null   int64
#  42  q_phone_serv          2000 non-null   int64
#  43  q_streaming           2000 non-null   int64
#  44  q_total_serv          2000 non-null   int64
#  45  zip_zone              2000 non-null   int64
#  46  contacts_by_month     2000 non-null   float64
# dtypes: float64(10), int64(18), object(19)
# memory usage: 750.0+ KB

# %% [markdown]
# ###Transformacion de variables cuantitativas

# %%
X_test[normal_cols] = sc.transform(X_test[normal_cols])
X_test[not_stander] = rs.transform(X_test[not_stander])
X_test.head()
# Out:
#            lat       lng  population      area  children       age employment  \
# 2585 -0.296451 -1.923534   -0.167466  Suburban       1.5  1.187500  Full Time
# 7801 -1.534669  0.314779    0.413602     Rural       1.0  1.312500  Full Time
# 2178  0.656004 -0.180530   -0.007666     Urban       0.0  0.437500  Full Time
# 5    -1.025491  0.235082    1.212438     Urban       1.0  1.229167  Full Time
# 8478  0.245996  0.086979   -0.236502     Rural       0.0  0.312500  Full Time
#
#         income        marital  gender  outage_sec_perweek     email  contacts  \
# 2585 -0.001185        Married    Male           -0.052302 -0.999483       0.5
# 7801  0.007454      Separated  Female           -0.374255 -0.336915      -0.5
# 2178  0.363215      Separated    Male            0.859189 -0.336915       0.5
# 5     0.067526  Never Married  Female           -0.535185  0.988219       1.0
# 8478 -0.381237      Separated    Male           -0.195843 -1.993334      -0.5
#
#       yearly_equip_failure techie        contract port_modem tablet  \
# 2585                   0.0     No        One year        Yes     No
# 7801                   0.0    Yes        Two Year        Yes     No
# 2178                   0.0     No  Month-to-month         No     No
# 5                      1.0     No        One year        Yes     No
# 8478                   0.0     No  Month-to-month         No    Yes
#
#      internetservice phone multiple onlinesecurity onlinebackup  \
# 2585     Fiber Optic   Yes      Yes             No          Yes
# 7801            None   Yes      Yes             No           No
# 2178     Fiber Optic   Yes       No             No           No
# 5               None   Yes      Yes            Yes          Yes
# 8478            None   Yes      Yes            Yes          Yes
#
#      deviceprotection techsupport streamingtv streamingmovies  \
# 2585               No       NS/NC          No              No
# 7801               No          No         Yes             Yes
# 2178               No          No         Yes             Yes
# 5                 Yes          No          No             Yes
# 8478               No          No         Yes              No
#
#      paperlessbilling             paymentmethod    tenure  monthlycharge  \
# 2585               No  Bank Transfer(automatic) -0.038407      -0.083914
# 7801               No              Mailed Check  0.856985       0.619474
# 2178              Yes   Credit Card (automatic) -0.255726       0.604300
# 5                  No          Electronic Check -0.189268       0.226531
# 8478              Yes  Bank Transfer(automatic)  0.792320      -0.112869
#
#       bandwidth_gb_year  timely_response  timely_fixes  timely_replacements  \
# 2585          -0.388914              1.0      0.475316                  1.0
# 7801           0.632397              0.0     -0.490773                  2.0
# 2178          -0.568980             -1.0     -0.490773                 -1.0
# 5             -0.502084              0.0     -0.490773                  0.0
# 8478           0.548622             -1.0     -1.456861                 -1.0
#
#       reliability  options  respectful_response  courteous_exchange  \
# 2585    -1.455665      1.0                  1.0            0.467559
# 7801    -1.455665      1.0                  1.0            0.467559
# 2178    -0.482302      2.0                 -1.0           -2.451646
# 5       -1.455665      1.0                  0.0           -0.505509
# 8478     0.491062     -2.0                  0.0           -0.505509
#
#       active_listening  total_encuesta  q_online_serv  q_phone_serv  \
# 2585         -0.489982        0.230168            0.0           0.0
# 7801          1.465547        0.460913           -1.0           0.0
# 2178         -0.489982       -1.615791           -0.5           0.0
# 5            -0.489982       -0.923556            0.0           1.0
# 8478         -0.489982       -1.846536            0.0           0.0
#
#       q_streaming  q_total_serv  zip_zone  contacts_by_month
# 2585         -1.0          -0.5      1.00           0.879051
# 7801          1.0          -0.5     -0.50          -0.150382
# 2178          1.0           0.0      0.00           4.477536
# 5             0.0           0.5     -0.50           3.204823
# 8478          0.0           0.0     -0.25          -0.150382

# %% [markdown]
# ###Transformacion con One Hot Encoder

# %%
#transformo el test en datasets en base a la clase generada en el entrenamiento
cat_encoding_test = pd.DataFrame(encoder.transform(X_test[cat_cols]), columns=encoder_cols)
cat_encoding_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 44 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   area_Rural                              2000 non-null   float64
#  1   area_Suburban                           2000 non-null   float64
#  2   area_Urban                              2000 non-null   float64
#  3   employment_Full Time                    2000 non-null   float64
#  4   employment_Part Time                    2000 non-null   float64
#  5   employment_Retired                      2000 non-null   float64
#  6   employment_Student                      2000 non-null   float64
#  7   employment_Unemployed                   2000 non-null   float64
#  8   marital_Divorced                        2000 non-null   float64
#  9   marital_Married                         2000 non-null   float64
#  10  marital_Never Married                   2000 non-null   float64
#  11  marital_Separated                       2000 non-null   float64
#  12  marital_Widowed                         2000 non-null   float64
#  13  gender_Female                           2000 non-null   float64
#  14  gender_Male                             2000 non-null   float64
#  15  gender_Prefer not to answer             2000 non-null   float64
#  16  techie_NS/NC                            2000 non-null   float64
#  17  techie_No                               2000 non-null   float64
#  18  techie_Yes                              2000 non-null   float64
#  19  contract_Month-to-month                 2000 non-null   float64
#  20  contract_One year                       2000 non-null   float64
#  21  contract_Two Year                       2000 non-null   float64
#  22  port_modem_Yes                          2000 non-null   float64
#  23  tablet_Yes                              2000 non-null   float64
#  24  internetservice_DSL                     2000 non-null   float64
#  25  internetservice_Fiber Optic             2000 non-null   float64
#  26  internetservice_None                    2000 non-null   float64
#  27  phone_NS/NC                             2000 non-null   float64
#  28  phone_No                                2000 non-null   float64
#  29  phone_Yes                               2000 non-null   float64
#  30  multiple_Yes                            2000 non-null   float64
#  31  onlinesecurity_Yes                      2000 non-null   float64
#  32  onlinebackup_Yes                        2000 non-null   float64
#  33  deviceprotection_Yes                    2000 non-null   float64
#  34  techsupport_NS/NC                       2000 non-null   float64
#  35  techsupport_No                          2000 non-null   float64
#  36  techsupport_Yes                         2000 non-null   float64
#  37  streamingtv_Yes                         2000 non-null   float64
#  38  streamingmovies_Yes                     2000 non-null   float64
#  39  paperlessbilling_Yes                    2000 non-null   float64
#  40  paymentmethod_Bank Transfer(automatic)  2000 non-null   float64
#  41  paymentmethod_Credit Card (automatic)   2000 non-null   float64
#  42  paymentmethod_Electronic Check          2000 non-null   float64
#  43  paymentmethod_Mailed Check              2000 non-null   float64
# dtypes: float64(44)
# memory usage: 687.6 KB

# %%
# Reseteamos el index para poder concatenarlo con el df de los cat_encoding:(si no hago esto,se alarga el dataset)

X_test.reset_index(inplace = True, drop=True)
y_test.reset_index(inplace = True, drop=True)

# %%
#joineo de las variables que deseo con categoricas encoding CON EL DF. AGREGO COLUMNAS AL DF
X_all_test = pd.concat([X_test, cat_encoding_test], axis=1)


#Borrado de columnas no necesarias
X_all_test.drop(['area', 'employment', 'marital', 'gender', 'techie', 'contract',
       'port_modem', 'tablet', 'internetservice', 'phone', 'multiple',
       'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
       'streamingtv', 'streamingmovies', 'paperlessbilling', 'paymentmethod'],axis=1, inplace=True)

#train datasets final
X_all_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 72 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   lat                                     2000 non-null   float64
#  1   lng                                     2000 non-null   float64
#  2   population                              2000 non-null   float64
#  3   children                                2000 non-null   float64
#  4   age                                     2000 non-null   float64
#  5   income                                  2000 non-null   float64
#  6   outage_sec_perweek                      2000 non-null   float64
#  7   email                                   2000 non-null   float64
#  8   contacts                                2000 non-null   float64
#  9   yearly_equip_failure                    2000 non-null   float64
#  10  tenure                                  2000 non-null   float64
#  11  monthlycharge                           2000 non-null   float64
#  12  bandwidth_gb_year                       2000 non-null   float64
#  13  timely_response                         2000 non-null   float64
#  14  timely_fixes                            2000 non-null   float64
#  15  timely_replacements                     2000 non-null   float64
#  16  reliability                             2000 non-null   float64
#  17  options                                 2000 non-null   float64
#  18  respectful_response                     2000 non-null   float64
#  19  courteous_exchange                      2000 non-null   float64
#  20  active_listening                        2000 non-null   float64
#  21  total_encuesta                          2000 non-null   float64
#  22  q_online_serv                           2000 non-null   float64
#  23  q_phone_serv                            2000 non-null   float64
#  24  q_streaming                             2000 non-null   float64
#  25  q_total_serv                            2000 non-null   float64
#  26  zip_zone                                2000 non-null   float64
#  27  contacts_by_month                       2000 non-null   float64
#  28  area_Rural                              2000 non-null   float64
#  29  area_Suburban                           2000 non-null   float64
#  30  area_Urban                              2000 non-null   float64
#  31  employment_Full Time                    2000 non-null   float64
#  32  employment_Part Time                    2000 non-null   float64
#  33  employment_Retired                      2000 non-null   float64
#  34  employment_Student                      2000 non-null   float64
#  35  employment_Unemployed                   2000 non-null   float64
#  36  marital_Divorced                        2000 non-null   float64
#  37  marital_Married                         2000 non-null   float64
#  38  marital_Never Married                   2000 non-null   float64
#  39  marital_Separated                       2000 non-null   float64
#  40  marital_Widowed                         2000 non-null   float64
#  41  gender_Female                           2000 non-null   float64
#  42  gender_Male                             2000 non-null   float64
#  43  gender_Prefer not to answer             2000 non-null   float64
#  44  techie_NS/NC                            2000 non-null   float64
#  45  techie_No                               2000 non-null   float64
#  46  techie_Yes                              2000 non-null   float64
#  47  contract_Month-to-month                 2000 non-null   float64
#  48  contract_One year                       2000 non-null   float64
#  49  contract_Two Year                       2000 non-null   float64
#  50  port_modem_Yes                          2000 non-null   float64
#  51  tablet_Yes                              2000 non-null   float64
#  52  internetservice_DSL                     2000 non-null   float64
#  53  internetservice_Fiber Optic             2000 non-null   float64
#  54  internetservice_None                    2000 non-null   float64
#  55  phone_NS/NC                             2000 non-null   float64
#  56  phone_No                                2000 non-null   float64
#  57  phone_Yes                               2000 non-null   float64
#  58  multiple_Yes                            2000 non-null   float64
#  59  onlinesecurity_Yes                      2000 non-null   float64
#  60  onlinebackup_Yes                        2000 non-null   float64
#  61  deviceprotection_Yes                    2000 non-null   float64
#  62  techsupport_NS/NC                       2000 non-null   float64
#  63  techsupport_No                          2000 non-null   float64
#  64  techsupport_Yes                         2000 non-null   float64
#  65  streamingtv_Yes                         2000 non-null   float64
#  66  streamingmovies_Yes                     2000 non-null   float64
#  67  paperlessbilling_Yes                    2000 non-null   float64
#  68  paymentmethod_Bank Transfer(automatic)  2000 non-null   float64
#  69  paymentmethod_Credit Card (automatic)   2000 non-null   float64
#  70  paymentmethod_Electronic Check          2000 non-null   float64
#  71  paymentmethod_Mailed Check              2000 non-null   float64
# dtypes: float64(72)
# memory usage: 1.1 MB

# %%
X_all_test.isnull().sum()[X_all_test.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ## *Prediccion*

# %%
y_pred = clf.predict(X_all_test)

# %% [markdown]
# ##*Metricas*

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1385,   85],
#        [ 115,  415]])

# %%
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred)

logreg_cm = confusion_matrix(y_test, y_pred)
tp, fp, fn, tn =  logreg_cm.ravel()
print(classification_report(y_test, y_pred))

pd.Series({'accuracy': acc,
              'f1_score' : f1,
              'auc': auc,
              'true positive': tp,
              'true negative': tn})
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93      1470
#            1       0.83      0.78      0.81       530
#
#     accuracy                           0.90      2000
#    macro avg       0.88      0.86      0.87      2000
# weighted avg       0.90      0.90      0.90      2000
# accuracy            0.900000
# f1_score            0.805825
# auc                 0.862598
# true positive    1385.000000
# true negative     415.000000
# dtype: float64

# %% [markdown]
# Precision: El 83% de las veces que dije que la persona iba a abandonar la compañia, la abandono. Tengo un 83% de probabilidades de acertarle a mi prediccion de churn.
#
# Recall: De todas las personas que abandonan la compañia, puedo predecir el 78%.
#
# F1_score: Nos referimos a un caclulo matematico que esta relacionado a la precision y al recall. En este modelo es del 80%

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(clf, X_all_test, y_test)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap


background_color = 'white' 
colormap = LinearSegmentedColormap.from_list("", ["lightgreen","lightgray"])


fig = plt.figure(figsize=(15,18)) 
fig.patch.set_facecolor(background_color) 
gs = fig.add_gridspec(5, 2)
gs.update(wspace=0.1, hspace=0.5)
ax0 = fig.add_subplot(gs[0, :])

#grafico de la matriz de confusion 
sns.heatmap(logreg_cm, linewidths=2.5,yticklabels=['No churn','Churn'],
            xticklabels=['Prediccion No churn','Prediccion Churn'], 
            cmap=colormap, 
            cbar=None,
            annot=True,
            fmt='d',
            ax=ax0,
            annot_kws={"fontsize":12}
            )

ax0.text(0, -0.3, 'Churn con LogisticRegression',fontsize=15, fontweight='bold', fontfamily='serif')
# Out:
# Text(0, -0.3, 'Churn con LogisticRegression')

# %%
importance = clf.coef_[0]
impo = pd.DataFrame(list(zip(X_all_test.columns, importance)), columns=['feature', 'importance'])
impo.sort_values('importance', ascending=False)

#estos valores de la tabla son los coeficientes. son 'a'. y x son los valores que venga en cada linea de la categoria.
# Out:
#                                    feature  importance
# 47                 contract_Month-to-month    2.054074
# 11                           monthlycharge    2.040720
# 52                     internetservice_DSL    1.104798
# 24                             q_streaming    0.915007
# 58                            multiple_Yes    0.574619
# 46                              techie_Yes    0.574573
# 66                     streamingmovies_Yes    0.506380
# 65                         streamingtv_Yes    0.387710
# 70          paymentmethod_Electronic Check    0.316306
# 8                                 contacts    0.310617
# 42                             gender_Male    0.278407
# 25                            q_total_serv    0.257464
# 56                                phone_No    0.212805
# 67                    paperlessbilling_Yes    0.191216
# 3                                 children    0.119672
# 62                       techsupport_NS/NC    0.113822
# 50                          port_modem_Yes    0.096152
# 39                       marital_Separated    0.082192
# 32                    employment_Part Time    0.078074
# 26                                zip_zone    0.065077
# 35                   employment_Unemployed    0.056375
# 40                         marital_Widowed    0.055133
# 61                    deviceprotection_Yes    0.052668
# 9                     yearly_equip_failure    0.039831
# 30                              area_Urban    0.030583
# 63                          techsupport_No    0.029129
# 14                            timely_fixes    0.024820
# 5                                   income    0.022956
# 28                              area_Rural    0.020430
# 15                     timely_replacements    0.009502
# 19                      courteous_exchange    0.007913
# 0                                      lat    0.006980
# 2                               population    0.006746
# 1                                      lng    0.006660
# 60                        onlinebackup_Yes    0.005165
# 7                                    email   -0.003486
# 20                        active_listening   -0.005003
# 37                         marital_Married   -0.007775
# 54                    internetservice_None   -0.008375
# 16                             reliability   -0.008856
# 4                                      age   -0.010624
# 31                    employment_Full Time   -0.014580
# 21                          total_encuesta   -0.016344
# 18                     respectful_response   -0.028309
# 36                        marital_Divorced   -0.045052
# 41                           gender_Female   -0.049413
# 13                         timely_response   -0.053248
# 34                      employment_Student   -0.054392
# 17                                 options   -0.059767
# 71              paymentmethod_Mailed Check   -0.059800
# 51                              tablet_Yes   -0.059932
# 27                       contacts_by_month   -0.060681
# 69   paymentmethod_Credit Card (automatic)   -0.062688
# 29                           area_Suburban   -0.071930
# 23                            q_phone_serv   -0.075865
# 55                             phone_NS/NC   -0.084271
# 33                      employment_Retired   -0.086394
# 38                   marital_Never Married   -0.105415
# 6                       outage_sec_perweek   -0.146239
# 57                               phone_Yes   -0.149451
# 22                           q_online_serv   -0.162106
# 44                            techie_NS/NC   -0.162385
# 64                         techsupport_Yes   -0.163868
# 59                      onlinesecurity_Yes   -0.194801
# 68  paymentmethod_Bank Transfer(automatic)   -0.214734
# 43             gender_Prefer not to answer   -0.249911
# 45                               techie_No   -0.433104
# 48                       contract_One year   -0.984765
# 49                       contract_Two Year   -1.090226
# 53             internetservice_Fiber Optic   -1.117340
# 10                                  tenure   -2.733203
# 12                       bandwidth_gb_year   -3.079719

# %% [markdown]
# ***Conclusion de la tabla:***
#
#
# Las siguientes variables son las que mas influyen la que las personas abandonen. Para que el modelo de 1.
#
# **contract_Month-to-month	a=2.054074**
#
#
# **monthlycharge	a=2.040720**
#
#
# **internetservice_DSL	a=1.104798**
#
#
#
#
# Las siguientes variables son las que mas influyen la que las personas NO abandonen es decir, para que el modelo de 0.
#
# **internetservice_Fiber Optic	a=-1.117340**
#
#
# **tenure	a=-2.733203**
#
#
# **bandwidth_gb_year	a=-3.079719**

# %%
from matplotlib import pyplot

# summarize feature importance
for i,v in zip(X_all_test.columns, importance):
	print('Feature: %s, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: lat, Score: 0.00698
# Feature: lng, Score: 0.00666
# Feature: population, Score: 0.00675
# Feature: children, Score: 0.11967
# Feature: age, Score: -0.01062
# Feature: income, Score: 0.02296
# Feature: outage_sec_perweek, Score: -0.14624
# Feature: email, Score: -0.00349
# Feature: contacts, Score: 0.31062
# Feature: yearly_equip_failure, Score: 0.03983
# Feature: tenure, Score: -2.73320
# Feature: monthlycharge, Score: 2.04072
# Feature: bandwidth_gb_year, Score: -3.07972
# Feature: timely_response, Score: -0.05325
# Feature: timely_fixes, Score: 0.02482
# Feature: timely_replacements, Score: 0.00950
# Feature: reliability, Score: -0.00886
# Feature: options, Score: -0.05977
# Feature: respectful_response, Score: -0.02831
# Feature: courteous_exchange, Score: 0.00791
# Feature: active_listening, Score: -0.00500
# Feature: total_encuesta, Score: -0.01634
# Feature: q_online_serv, Score: -0.16211
# Feature: q_phone_serv, Score: -0.07587
# Feature: q_streaming, Score: 0.91501
# Feature: q_total_serv, Score: 0.25746
# Feature: zip_zone, Score: 0.06508
# Feature: contacts_by_month, Score: -0.06068
# Feature: area_Rural, Score: 0.02043
# Feature: area_Suburban, Score: -0.07193
# Feature: area_Urban, Score: 0.03058
# Feature: employment_Full Time, Score: -0.01458
# Feature: employment_Part Time, Score: 0.07807
# Feature: employment_Retired, Score: -0.08639
# Feature: employment_Student, Score: -0.05439
# Feature: employment_Unemployed, Score: 0.05638
# Feature: marital_Divorced, Score: -0.04505
# Feature: marital_Married, Score: -0.00777
# Feature: marital_Never Married, Score: -0.10542
# Feature: marital_Separated, Score: 0.08219
# Feature: marital_Widowed, Score: 0.05513
# Feature: gender_Female, Score: -0.04941
# Feature: gender_Male, Score: 0.27841
# Feature: gender_Prefer not to answer, Score: -0.24991
# Feature: techie_NS/NC, Score: -0.16239
# Feature: techie_No, Score: -0.43310
# Feature: techie_Yes, Score: 0.57457
# Feature: contract_Month-to-month, Score: 2.05407
# Feature: contract_One year, Score: -0.98477
# Feature: contract_Two Year, Score: -1.09023
# Feature: port_modem_Yes, Score: 0.09615
# Feature: tablet_Yes, Score: -0.05993
# Feature: internetservice_DSL, Score: 1.10480
# Feature: internetservice_Fiber Optic, Score: -1.11734
# Feature: internetservice_None, Score: -0.00837
# Feature: phone_NS/NC, Score: -0.08427
# Feature: phone_No, Score: 0.21281
# Feature: phone_Yes, Score: -0.14945
# Feature: multiple_Yes, Score: 0.57462
# Feature: onlinesecurity_Yes, Score: -0.19480
# Feature: onlinebackup_Yes, Score: 0.00517
# Feature: deviceprotection_Yes, Score: 0.05267
# Feature: techsupport_NS/NC, Score: 0.11382
# Feature: techsupport_No, Score: 0.02913
# Feature: techsupport_Yes, Score: -0.16387
# Feature: streamingtv_Yes, Score: 0.38771
# Feature: streamingmovies_Yes, Score: 0.50638
# Feature: paperlessbilling_Yes, Score: 0.19122
# Feature: paymentmethod_Bank Transfer(automatic), Score: -0.21473
# Feature: paymentmethod_Credit Card (automatic), Score: -0.06269
# Feature: paymentmethod_Electronic Check, Score: 0.31631
# Feature: paymentmethod_Mailed Check, Score: -0.05980
